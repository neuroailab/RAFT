# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '6'

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms

import matplotlib.pyplot as plt
import cv2
from PIL import Image

import mediapy as media
import PIL
import io

import matplotlib.patches
import seaborn as sns
from IPython.display import HTML as html_print


# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
sys.path.append('../core')

from raft import RAFT
from train import get_args, load_model
import datasets as raft_datasets
import teachers
import utils.flow_viz as flow_viz
import matplotlib

def segmentation_to_rgb(seg, palette=None, num_objects=None, bg_color=(0, 0, 0)):
    if num_objects is None:
        num_objects = np.max(seg)  # assume consecutive numbering
    num_objects += 1  # background
    if palette is None:
        palette = [bg_color] + sns.color_palette('hls', num_objects-1)

    seg_img = np.zeros((seg.shape[0], seg.shape[1], 3), dtype=np.float32)
    for i in range(num_objects):
        seg_img[np.nonzero(seg[:, :, 0] == i)] = palette[i]
    return seg_img

def depth_to_rgb(depth, colormap=matplotlib.cm.viridis_r, sqrt=True):
    cmap = np.array(colormap.colors)
    if sqrt:
        d = np.round(np.sqrt((depth[..., 0] / 65535).clip(0, 1.)) * 255).astype(np.uint8)
    else:
        d = np.round(depth[..., 0] // 256).astype(np.uint8)
    return cmap[d]

def flow_to_rgb(vec, flow_mag_range=None, white_bg=False):
    height, width = vec.shape[:2]
    scaling = 50. / (height**2 + width**2)**0.5
    direction = (np.arctan2(vec[..., 0], vec[..., 1]) + np.pi) / (2 * np.pi)
    norm = np.linalg.norm(vec, axis=-1)
    if flow_mag_range is None:
        flow_mag_range = norm.min(), norm.max()
        magnitude = np.clip((norm - flow_mag_range[0]) * scaling, 0., 1.)
    if white_bg == True:
        value = np.ones_like(direction)
        hsv = np.stack([direction, magnitude, saturation], axis=-1)
    else:
        saturation = np.ones_like(direction)
        hsv = np.stack([direction, saturation , magnitude], axis=-1)
        rgb = matplotlib.colors.hsv_to_rgb(hsv)
    return rgb
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:513: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:521: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:555: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:565: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/tensor_util.py:107: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object:
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/framework/tensor_util.py:109: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool:
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py:546: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class IteratorBase(collections.Iterator, trackable.Trackable,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:106: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class DatasetV2(collections.Iterable, tracking_base.Trackable,
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:696: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   collections.MutableMapping.register(ParseResults)
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:2273: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   elif isinstance( exprs, collections.Sequence ):

# %%
import dorsalventral.models.targets as targets
import dorsalventral.vis_utils as vis_utils
import dorsalventral.data as datasets
import dorsalventral.data.utils as data_utils
import dorsalventral.models.fire_propagation as fprop
import dorsalventral.models.layer_utils as layer_utils
import dorsalventral.models.segmentation.competition as competition
import dorsalventral.models.losses as losses
import kornia
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
#     root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
    root='/mnt/fs5/dbear/tdw_datasets/playroom_large_v3/',
#     dataset_names=['model_split_4'],    
    dataset_names=['model_split_%d' % split for split in range(5)],
    split='validation',
    filepattern="*",
#     test_filepattern="0*[0-4]",
    test_filepattern="*9",
    min_start_frame=5,
    max_start_frame=5,
    scale_to_pixels=True,
    get_gt_flow=True,
    get_backward_frame=True
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)


data_dir = '/mnt/fs6/honglinc/dataset/tensorflow_datasets/movi_d/256x256/1.0.0'
movi_dataset = datasets.movi.MoviDataset(
    dataset_dir=data_dir,
    split='validation',
    sequence_length=2,
    min_start_frame=0,
    max_start_frame=None,
    is_test=False
)
print(len(movi_dataset))


movi_eval_dataset = datasets.movi.MoviEvalDataset(
    dataset_dir=data_dir,
    split='validation',
    sequence_length=2,
    to_jax=False
)
print(len(movi_eval_dataset))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 625
# True
# /home/dbear/tenv/lib/python3.7/site-packages/tensorflow/python/ops/numpy_ops/np_random.py:95: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def randint(low, high=None, size=None, dtype=onp.int):  # pylint: disable=missing-function-docstring
# 250
# 250

# %%
# forward_flow = data['flow'].permute(0,2,3,1).numpy()
# minv, maxv = movi_eval_dataset.meta["forward_flow_range"]
# forward_flow = forward_flow / 65535 * (maxv - minv) + minv


# media.show_videos({"rgb": data['images'].permute(0,2,3,1).numpy(),
#                    "segmentation": [segmentation_to_rgb(s, num_objects=movi_eval_dataset.meta["num_instances"])
#                                     for s in data["objects"].permute(0,2,3,1).numpy()],
#                    "forward_flow": flow_to_rgb(forward_flow, white_bg=False),
                   
#                    },
#                 fps=8,
#                 columns=3,
#                 codec="gif",
# )
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Build the full grouping and tracking model

# %%
# motion_paths = !ls ../checkpoints/[0-9]*motion*dtarg*nthr05*fullplay*pretrained*
# motion_paths = !ls ../checkpoints/[0-9]*motion*tdw*nthr0-cthr025*

# motion_paths = !ls ../checkpoints/[0-9]*motion*movi_d*bs2*nthr0-*gs1*
# motion_paths = !ls ../checkpoints/[0-9]*motion*rnd1*movi_d*bs2*gs1*
motion_paths = !ls ../checkpoints/[0-9]*motion*rnd1*movi_d*bs2*small*gs1*

motion_paths = sorted(motion_paths, key=lambda s: int(s.split('/')[-1].split('_')[0]))
# !ls ../checkpoints/*motion*imtarg*thr0*
for i,p in enumerate(motion_paths):
    print(i, p)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0 ../checkpoints/5000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 1 ../checkpoints/10000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 2 ../checkpoints/15000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 3 ../checkpoints/20000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 4 ../checkpoints/25000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 5 ../checkpoints/30000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 6 ../checkpoints/35000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 7 ../checkpoints/40000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 8 ../checkpoints/45000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 9 ../checkpoints/50000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 10 ../checkpoints/55000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 11 ../checkpoints/60000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 12 ../checkpoints/65000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 13 ../checkpoints/70000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 14 ../checkpoints/75000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 15 ../checkpoints/80000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 16 ../checkpoints/85000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 17 ../checkpoints/90000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 18 ../checkpoints/95000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# 19 ../checkpoints/100000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth

# %%
# boundary_paths = !ls ../checkpoints/[0-9]*boundary*rnd1*dtarg*fullplay*pretrained*

# boundary_paths = !ls ../checkpoints/[0-9]*boundaryStaticReg*rnd0*cthr075*fullplay*rerun*
# boundary_paths = !ls ../checkpoints/[0-9]*boundaryMotionReg*rnd0*small*nthr0*cthr075*fullplay*
# boundary_paths = !ls ../checkpoints/[0-9]*boundaryMotionReg*rnd1*tdw*small*

# boundary_paths = !ls ../checkpoints/[0-9]*boundaryStatic*rnd0*movi_d*nthr0-*gs1*
# boundary_paths = !ls ../checkpoints/100000*boundaryMotion*rnd0*movi_d*nthr0-*gs1*

boundary_paths = !ls ../checkpoints/[0-9]*boundaryMotion*rnd1*movi_d*small*gs1*-1*
# boundary_paths = !ls ../checkpoints/100000*boundaryMotion*rnd0*movi_d*gs1*


boundary_paths = sorted(boundary_paths, key=lambda s: int(s.split('/')[-1].split('_')[0]))
for i,p in enumerate(boundary_paths):
    print(i, p)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0 ../checkpoints/2500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 1 ../checkpoints/5000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 2 ../checkpoints/7500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 3 ../checkpoints/10000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 4 ../checkpoints/12500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 5 ../checkpoints/15000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 6 ../checkpoints/17500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 7 ../checkpoints/20000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 8 ../checkpoints/22500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 9 ../checkpoints/25000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 10 ../checkpoints/27500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 11 ../checkpoints/30000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 12 ../checkpoints/32500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 13 ../checkpoints/35000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 14 ../checkpoints/37500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 15 ../checkpoints/40000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 16 ../checkpoints/42500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 17 ../checkpoints/45000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 18 ../checkpoints/47500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 19 ../checkpoints/50000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 20 ../checkpoints/52500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 21 ../checkpoints/55000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 22 ../checkpoints/57500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 23 ../checkpoints/60000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 24 ../checkpoints/62500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 25 ../checkpoints/65000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 26 ../checkpoints/67500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 27 ../checkpoints/70000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 28 ../checkpoints/72500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 29 ../checkpoints/75000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 30 ../checkpoints/77500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 31 ../checkpoints/80000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 32 ../checkpoints/82500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 33 ../checkpoints/85000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 34 ../checkpoints/87500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 35 ../checkpoints/90000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 36 ../checkpoints/92500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 37 ../checkpoints/95000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 38 ../checkpoints/97500_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# 39 ../checkpoints/100000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth

# %%
# flow_paths = !ls ../checkpoints/[0-9]*flowBoundary*bmt*movi_d*gs1*
# flow_paths = !ls ../checkpoints/[0-9]*flowBoundary*rnd0*movi_d*gs1*
# flow_paths = !ls ../checkpoints/[0-9]*flowBoundary*rnd1*movi_d*large*gs1*
# flow_paths = !ls ../checkpoints/100000*flowBoundary*rnd1*movi_d*small*gs1*
flow_paths = !ls ../checkpoints/[0-9]*flowCentroids*rnd2*movi_d*small*gs1*

# flow_paths = !ls ../checkpoints/[0-9]*flowBoundary*tdw*
# flow_paths = !ls ../checkpoints/100000*flowBoundary*rnd0*movi_d*gs1*


flow_paths = sorted(flow_paths, key=lambda s: int(s.split('/')[-1].split('_')[0]))
# !ls ../checkpoints/*motion*imtarg*thr0*
for i,p in enumerate(flow_paths):
    print(i, p)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0 ../checkpoints/7500_flowCentroids-rnd2-movi_d-bs2-small-gs1-noEisen-Bootstrap-maskTarget-pretrained-0.pth

# %%
# e_path = '../checkpoints/80000_eisen_teacher_v1_128_bs4.pth'
e_path = '../checkpoints/30000_eisen_teacher_v1_64_bs16.pth'

print(e_path)
# Out:
# ../checkpoints/30000_eisen_teacher_v1_64_bs16.pth
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
m_idx = -1
b_idx = -1
f_idx = -1
m_path = motion_paths[m_idx]
b_path = boundary_paths[b_idx]
f_path = flow_paths[f_idx]
boot_paths = {
    'motion_path': m_path,
    'boundary_path': b_path,
    'flow_path': f_path
}


stride = 4
T_group = 2
T_track = 1
T = 2
use_gt = False
use_eisen = True
if use_eisen:
    static_path = e_path
elif use_gt:
    static_path = 'ground_truth'
else:
    static_path = None

BBNet = teachers.BipartiteBootNet(
    student_model_type='flow_centroids',
#     target_model_params={},
    static_path=static_path,
#     static_params={'radius': 7},
    static_params={'stem_pool': (stride == 4), 'affinity_res': [256//stride,256//stride]},
    input_keys={'static': 'objects'} if use_gt else {},
    boot_paths=boot_paths,
    downsample_factor=stride,
    grouping_window=T_group,
    tracking_step_size=T_track,
    static_resolution=4,
    dynamic_resolution=3
).cuda().eval()


data_dir = '/mnt/fs6/honglinc/dataset/tensorflow_datasets/movi_d/256x256/1.0.0'
movi_dataset = datasets.movi.MoviDataset(
    dataset_dir=data_dir,
    split='validation',
    sequence_length=T,
    min_start_frame=12,
    max_start_frame=12,
    is_test=False
)
print(len(movi_dataset))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Plateau map dimensions: [stat 16, dyn 9, rand 0, total 144]
# <All keys matched successfully> MotionClassifier ../checkpoints/100000_motion-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-0.pth
# <All keys matched successfully> BoundaryClassifier ../checkpoints/100000_boundaryMotionReg-rnd1-movi_d-bs2-small-mt05-bt05-flit24-gs1-pretrained-1.pth
# <All keys matched successfully> RAFT ../checkpoints/7500_flowCentroids-rnd2-movi_d-bs2-small-gs1-noEisen-Bootstrap-maskTarget-pretrained-0.pth
# LOAD EISEN
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['teacher.motion_model.fnet.conv1.weight', 'teacher.motion_model.fnet.conv1.bias', 'teacher.motion_model.fnet.layer1.0.conv1.weight', 'teacher.motion_model.fnet.layer1.0.conv1.bias', 'teacher.motion_model.fnet.layer1.0.conv2.weight', 'teacher.motion_model.fnet.layer1.0.conv2.bias', 'teacher.motion_model.fnet.layer1.1.conv1.weight', 'teacher.motion_model.fnet.layer1.1.conv1.bias', 'teacher.motion_model.fnet.layer1.1.conv2.weight', 'teacher.motion_model.fnet.layer1.1.conv2.bias', 'teacher.motion_model.fnet.layer2.0.conv1.weight', 'teacher.motion_model.fnet.layer2.0.conv1.bias', 'teacher.motion_model.fnet.layer2.0.conv2.weight', 'teacher.motion_model.fnet.layer2.0.conv2.bias', 'teacher.motion_model.fnet.layer2.0.downsample.0.weight', 'teacher.motion_model.fnet.layer2.0.downsample.0.bias', 'teacher.motion_model.fnet.layer2.1.conv1.weight', 'teacher.motion_model.fnet.layer2.1.conv1.bias', 'teacher.motion_model.fnet.layer2.1.conv2.weight', 'teacher.motion_model.fnet.layer2.1.conv2.bias', 'teacher.motion_model.fnet.layer3.0.conv1.weight', 'teacher.motion_model.fnet.layer3.0.conv1.bias', 'teacher.motion_model.fnet.layer3.0.conv2.weight', 'teacher.motion_model.fnet.layer3.0.conv2.bias', 'teacher.motion_model.fnet.layer3.0.downsample.0.weight', 'teacher.motion_model.fnet.layer3.0.downsample.0.bias', 'teacher.motion_model.fnet.layer3.1.conv1.weight', 'teacher.motion_model.fnet.layer3.1.conv1.bias', 'teacher.motion_model.fnet.layer3.1.conv2.weight', 'teacher.motion_model.fnet.layer3.1.conv2.bias', 'teacher.motion_model.fnet.conv2.weight', 'teacher.motion_model.fnet.conv2.bias', 'teacher.motion_model.cnet.norm1.weight', 'teacher.motion_model.cnet.norm1.bias', 'teacher.motion_model.cnet.norm1.running_mean', 'teacher.motion_model.cnet.norm1.running_var', 'teacher.motion_model.cnet.norm1.num_batches_tracked', 'teacher.motion_model.cnet.conv1.weight', 'teacher.motion_model.cnet.conv1.bias', 'teacher.motion_model.cnet.layer1.0.conv1.weight', 'teacher.motion_model.cnet.layer1.0.conv1.bias', 'teacher.motion_model.cnet.layer1.0.conv2.weight', 'teacher.motion_model.cnet.layer1.0.conv2.bias', 'teacher.motion_model.cnet.layer1.0.norm1.weight', 'teacher.motion_model.cnet.layer1.0.norm1.bias', 'teacher.motion_model.cnet.layer1.0.norm1.running_mean', 'teacher.motion_model.cnet.layer1.0.norm1.running_var', 'teacher.motion_model.cnet.layer1.0.norm1.num_batches_tracked', 'teacher.motion_model.cnet.layer1.0.norm2.weight', 'teacher.motion_model.cnet.layer1.0.norm2.bias', 'teacher.motion_model.cnet.layer1.0.norm2.running_mean', 'teacher.motion_model.cnet.layer1.0.norm2.running_var', 'teacher.motion_model.cnet.layer1.0.norm2.num_batches_tracked', 'teacher.motion_model.cnet.layer1.1.conv1.weight', 'teacher.motion_model.cnet.layer1.1.conv1.bias', 'teacher.motion_model.cnet.layer1.1.conv2.weight', 'teacher.motion_model.cnet.layer1.1.conv2.bias', 'teacher.motion_model.cnet.layer1.1.norm1.weight', 'teacher.motion_model.cnet.layer1.1.norm1.bias', 'teacher.motion_model.cnet.layer1.1.norm1.running_mean', 'teacher.motion_model.cnet.layer1.1.norm1.running_var', 'teacher.motion_model.cnet.layer1.1.norm1.num_batches_tracked', 'teacher.motion_model.cnet.layer1.1.norm2.weight', 'teacher.motion_model.cnet.layer1.1.norm2.bias', 'teacher.motion_model.cnet.layer1.1.norm2.running_mean', 'teacher.motion_model.cnet.layer1.1.norm2.running_var', 'teacher.motion_model.cnet.layer1.1.norm2.num_batches_tracked', 'teacher.motion_model.cnet.layer2.0.conv1.weight', 'teacher.motion_model.cnet.layer2.0.conv1.bias', 'teacher.motion_model.cnet.layer2.0.conv2.weight', 'teacher.motion_model.cnet.layer2.0.conv2.bias', 'teacher.motion_model.cnet.layer2.0.norm1.weight', 'teacher.motion_model.cnet.layer2.0.norm1.bias', 'teacher.motion_model.cnet.layer2.0.norm1.running_mean', 'teacher.motion_model.cnet.layer2.0.norm1.running_var', 'teacher.motion_model.cnet.layer2.0.norm1.num_batches_tracked', 'teacher.motion_model.cnet.layer2.0.norm2.weight', 'teach ...
# 250

# %%
ex = 0
# data = movi_eval_dataset[ex]
for e in range(ex+1):
    data = movi_dataset[e]
video = data['images']
print("video", video.shape)
# preds, plateau, segments, full_segments = BBNet(video[None].cuda())
bbnet_preds = BBNet(
    video[None].cuda(),
#     {k:data[k][None].cuda() for k in ['images', 'objects']},
    boot_params={'bootstrap': False, 'flow_iters': 12},
    static_params={'to_image': True, 'local_window_size': None},
    mask_with_motion=False
)
if BBNet.student_model_type is None:
    preds, plateau, segments, full_segments = bbnet_preds
    mask = preds[-1][:,:,0,...,None]
elif BBNet.student_model_type in ['flow', 'flow_centroids']:
    s2m_target = bbnet_preds
elif BBNet.student_model_type in ['centroids']:
    dcentroid_target, thingness = bbnet_preds
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# movie, frame b'3835' 12
# video torch.Size([2, 3, 256, 256])

# %%
fig, axes = plt.subplots(1,2,figsize=(8,4))
vis_utils.imshow(data_utils.FlowToRgb(40.0)(
    dcentroid_target), axes[1])
vis_utils.imshow(thingness, axes[0], cmap='inferno', vmin=0, vmax=1)

titles = ['T(thingness)', 'T(centroidOffsets)']
for i,ax in enumerate(axes):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(titles[i], fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f923d451add7> in <module>
#       1 fig, axes = plt.subplots(1,2,figsize=(8,4))
#       2 vis_utils.imshow(data_utils.FlowToRgb(40.0)(
# ----> 3     dcentroid_target), axes[1])
#       4 vis_utils.imshow(thingness, axes[0], cmap='inferno', vmin=0, vmax=1)
#       5
#
# NameError: name 'dcentroid_target' is not defined

# %%
vis_utils.imshow(
    data_utils.FlowToRgb(2.0)(
        s2m_target[:,0]))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
T_full = full_segments.shape[1]
fig, axes = plt.subplots(2,T_full, figsize=(4*T_full, 8))
for t in range(T_full):
    vis_utils.imshow(data['images'][None,t], axes[0][t])
    vis_utils.imshow(full_segments[:,t,None], axes[1][t], cmap='twilight', vmin=-1, vmax=33)
    for ax in axes[:,t]:
        ax.set_xticks([])
        ax.set_yticks([])
plt.tight_layout()
plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e887c24fbd4c> in <module>
# ----> 1 T_full = full_segments.shape[1]
#       2 fig, axes = plt.subplots(2,T_full, figsize=(4*T_full, 8))
#       3 for t in range(T_full):
#       4     vis_utils.imshow(data['images'][None,t], axes[0][t])
#       5     vis_utils.imshow(full_segments[:,t,None], axes[1][t], cmap='twilight', vmin=-1, vmax=33)
#
# NameError: name 'full_segments' is not defined

# %%
fig, axes = plt.subplots(3,plateau.shape[1],figsize=(4*plateau.shape[1],12))
for i in range(plateau.shape[1]):
    vis_utils.imshow(plateau[:,i:i+1].argmax(-1), axes[0,i], cmap='twilight', vmin=0, vmax=plateau.shape[-1]+1)   
    vis_utils.imshow(segments[:,i:i+1], axes[1,i], cmap='twilight', vmin=-1, vmax=33)
    vis_utils.imshow(video[i:i+1] / 255., axes[2,i])
    axes[0,i].set_xticks([])
    axes[0,i].set_yticks([])
    axes[1,i].set_xticks([])
    axes[1,i].set_yticks([])   
    axes[2,i].set_xticks([])
    axes[2,i].set_yticks([])       
    axes[0,i].set_title('plateau frame %d' % i, fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import dorsalventral.evaluation.object_metrics as om
T_eval = T
segments_rz = transforms.Resize([256,256], interpolation=transforms.InterpolationMode.NEAREST)(full_segments)
print(T_eval, segments_rz.shape)
ari = om.adjusted_rand_index(
    pred_ids=(full_segments[:,:T_eval]+1).long(),
    true_ids=data['objects'][None,:T_eval,0,::BBNet.stride,::BBNet.stride].long().cuda(),
    num_instances_pred=(full_segments[:,:T_eval]+1).amax().item()+1,
    num_instances_true=data['objects'][:T_eval].amax().item()+1,
    ignore_background=True
)
print(ari)

ari = om.adjusted_rand_index(
    pred_ids=(segments_rz[:,:T_eval]+1).long(),
    true_ids=data['objects'][None,:T_eval,0].long().cuda(),
    num_instances_pred=(segments_rz[:,:T_eval]+1).amax().item()+1,
    num_instances_true=data['objects'][:T_eval].amax().item()+1,
    ignore_background=True
)
print(ari)
# Out:
# 2 torch.Size([1, 2, 256, 256])
# tensor([0.7047], device='cuda:0')
# tensor([0.7036], device='cuda:0')
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(data_utils.FlowToRgb(3.0)(preds[3][:,0]))
vis_utils.imshow(data_utils.FlowToRgb(3.0)(preds[4][:,0]))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
CTarget = targets.CentroidTarget(
        compute_offsets=True,
        normalize=True,
        scale_to_px=True,
        thresh=0.5
    ).cuda()

FU = targets.FuturePredictionTarget().cuda()
motion_mask = preds[-1][0]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
masks = F.one_hot(full_segments.view(-1,*full_segments.shape[-2:]), num_classes=32).permute(0,3,1,2).float()
target, masks = CTarget(masks * motion_mask)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dcentroids = (target * masks[:,:,None] * preds[-1][0,:,None]).sum(1)[None]
ftarget, _ = FU(dcentroids)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(data_utils.FlowToRgb(50.0)((target * masks[:,:,None] * preds[-1][0,:,None]).sum(1)))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
vis_utils.imshow(data_utils.FlowToRgb(3.0)((ftarget * preds[-1][0,0:1,None])[0]))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
MC = teachers.StaticToMotionTeacher().cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
target = MC(full_segments, preds[-1])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
target.shape
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# torch.Size([1, 1, 2, 128, 128])

# %%
vis_utils.imshow(data_utils.FlowToRgb(3.0)(target[:,0] * motion_mask[:,0]))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
LocalCT = targets.CentroidTarget(local_strides=[1,2,4,8], return_masks=True, scale_to_px=True).cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
motion_mask = preds[-1][0]
local_targets = LocalCT(masks * motion_mask)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(
    data_utils.FlowToRgb(20.0)(
        local_targets[0][0:1,-2:] * motion_mask
    )
)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
motion_mask = preds[-1][0]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
m = 2
vis_utils.imshow((masks * motion_mask)[:,m,None])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
local_ftarget, _ = FU(local_targets[0][None])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(
    data_utils.FlowToRgb(1.0)(
        local_ftarget[0] * motion_mask[:,0:1]
    )
)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# LMC = teachers.StaticToMotionTeacher(local_strides=[1,2,4,8,16]).cuda()
LMC = teachers.StaticToMotionTeacher(local_strides=None).cuda()

local_ftarget = LMC(full_segments[:,0:2], preds[-1])
# Out:
# local []
# target torch.Size([2, 31, 2, 128, 128])
# loss_mask torch.Size([2, 31, 128, 128])
# motion_mask torch.Size([2, 1, 1, 128, 128])
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(
    data_utils.FlowToRgb(1.0)(
        local_ftarget[:,0]
    )
)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
vis_utils.imshow(
    data_utils.FlowToRgb(3.0)(
        local_ftarget[:,0]
    )
)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
