# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms

import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
sys.path.append('../core')

from raft import RAFT
from train import get_args
import datasets as raft_datasets
import utils.flow_viz as flow_viz

def set_args(args_dict={}):
    args = get_args("")
    for k,v in args_dict.items():
        args.__setattr__(k, v)
    return args

def tensor_to_arr(tensor, ex=0):
    if len(tensor.shape) == 4:
        tensor = tensor[ex]
    return tensor.detach().permute(1, 2, 0).cpu().numpy()

def viz(tensor, ex=0):
    im = tensor_to_arr(tensor, ex)
    if im.max() > 2.0:
        im = im / 255.0
    plt.imshow(im)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:696: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   collections.MutableMapping.register(ParseResults)
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:2273: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   elif isinstance( exprs, collections.Sequence ):
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:568: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.object, string),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:569: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.bool, bool),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:593: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:597: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:614: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING_REF: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:619: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL_REF: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:100: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object: SlowAppendObjectArrayToTensorProto,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:101: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool: SlowAppendBoolArrayToTensorProto,

# %% [markdown]
# ## Flows are coded as (x, y) where +y is upward in the image; value is in pixels

# %%
chairs_dataset = raft_datasets.FlyingChairs(
    root='../datasets/FlyingChairs_release/data',
    split='validation', 
    split_file='../chairs_split.txt')
print(len(chairs_dataset))
img1, img2, flow, valid = chairs_dataset[0]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 640

# %%
from bootraft import BootRaft
args = set_args()
net = torch.nn.DataParallel(RAFT(args))
# net = torch.nn.DataParallel(BootRaft(args))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ls ../checkpoints/*amaxtotal*
# Out:
# ../checkpoints/10000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/15000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/20000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/25000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/30000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/35000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/40000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/45000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/50000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/5000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/55000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/60000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/65000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/70000_raft-tdw-bn-amaxtotalenergyframes.pth
# ../checkpoints/75000_raft-tdw-bn-amaxtotalenergyframes.pth
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
load_path = '../checkpoints/75000_raft-tdw-bn-amaxtotalenergyframes.pth'
# load_path = '../models/raft-sintel.pth'
net.load_state_dict(torch.load(load_path), strict=False)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <All keys matched successfully>

# %%
net.cuda()
net.eval()
net.module.freeze_bn()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
    root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
#     root='/mnt/fs5/dbear/tdw_datasets/primitives_large_v1/',
#     root='/mnt/fs5/dbear/tdw_datasets/playroom_large_v3/',
    dataset_names=['model_split_4'],    
#     dataset_names=['model_split_%d' % split for split in range(32)],
    split='training',
    filepattern="*",
    test_filepattern="0*[0-4]",
    min_start_frame=5,
    max_start_frame=5,
    scale_to_pixels=True,
    get_gt_flow=True,
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)
# Out:
# 1250
# False
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def viz_raft_prediction(model, dataset, ex=0, iters=[1,12,24]):
    dataset.is_test = False
    if ex is None:
        ex = np.random.randint(0, len(dataset))
    img1, img2, gt, _ = dataset[ex]
    preds = []
    if not isinstance(iters, list):
        iters = [iters]
    for it in iters:
        _, pred = model(img1[None].cuda(), img2[None].cuda(), iters=it, test_mode=True)
        pred = flow_viz.flow_to_image(tensor_to_arr(pred))
        preds.append(pred)
    _flow_gt = flow_viz.flow_to_image(tensor_to_arr(gt))

    fig, axes = plt.subplots(1,2 + len(iters),figsize=(8 + 4*len(iters),4))
    axes[0].imshow(img1.permute(1, 2, 0).numpy() / 255.)
    for i in range(len(iters)):
        axes[1+i].imshow(preds[i])
    axes[-1].imshow(_flow_gt)
    
    titles = ['img1'] + ['pred @ %d iters' % it for it in iters] + ['gt']
    
    for i, ax in enumerate(axes):
        ax.set_title(titles[i], fontsize=18)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.tight_layout()
    plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
viz_raft_prediction(net, tdw_dataset, ex=3, iters=[1,6,12,24])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def normalize(img):
    return 2.0 * (img / 255.) - 1.0
img1, img2, flow, _ = tdw_dataset[1]
# fmap1, fmap2 = net.module.fnet([normalize(img1[None].cuda()), normalize(img2[None].cuda())])
# ctx = net.module.cnet(img1[None].cuda())
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from tqdm import tqdm
DEFAULT_CMAP = plt.cm.twilight
DEFAULT_ERRMAP_COLORS = {k:float(v)/DEFAULT_CMAP.N for k,v in {'tp': 250, 'tn': 0, 'fp': 420, 'fn': 80}.items()}

def plot_errormap(model, dataset, ex=None, iters=24, thresh=4, 
                  cmap=DEFAULT_CMAP,
                  colors=DEFAULT_ERRMAP_COLORS,
                  do_plot=True,
                  return_errormap=True,
                  return_images=False,
                 ):
    if ex is None:
        ex = np.random.randint(len(dataset))
        
    blob = dataset[ex]
    try:
        img1, img2, flow = blob[:3]
    except:
        img1, img2 = blob[:2]
        flow = torch.zeros_like(img1[:2])
    _, pred = model(img1[None].cuda(), img2[None].cuda(), iters=iters, test_mode=True)
    
    _seg = lambda x, t: (x.square().sum(-3).sqrt() > t).cpu().numpy()[0]
    pred_seg = _seg(pred, thresh)
    gt_seg = _seg(flow[None], 0.5)
    
    tp = pred_seg & gt_seg
    tn = ~pred_seg & ~gt_seg
    fp = pred_seg & ~gt_seg
    fn = ~pred_seg & gt_seg
    n = (pred_seg | gt_seg).sum() + 0.
    
    metrics = {
        'iou': tp.sum() / n,
        'precision': (tp.sum() + 0.) / (tp.sum() + fp.sum()),
        'recall': (tp.sum() + 0.) / (tp.sum() + fn.sum())
    }

    errmap = np.zeros(list(gt_seg.shape) + [3])
    errmap[pred_seg & gt_seg] = list(cmap(colors['tp']))[:3]
    errmap[~pred_seg & ~gt_seg] = list(cmap(colors['tn']))[:3]
    errmap[pred_seg & ~gt_seg] = list(cmap(colors['fp']))[:3]
    errmap[~pred_seg & gt_seg] = list(cmap(colors['fn']))[:3]
    
    if do_plot:
        plt.imshow(errmap)
        plt.xticks([])
        plt.yticks([])
        plt.show()
    elif return_errormap:
        metrics['error_map'] = errmap
        
    if return_images:
        metrics.update({
            'image1': img1.permute(1, 2, 0).cpu().numpy() / 255.,
            'image2': img2.permute(1, 2, 0).cpu().numpy() / 255.,
            'pred': flow_viz.flow_to_image(tensor_to_arr(pred[0])),
            'gt': flow_viz.flow_to_image(tensor_to_arr(flow))
        })
    
    return metrics

def visualize_error_maps(model, dataset, examples=[0], iters=24, thresh=4, max_examples=5):
    
    def val_fn(ex):
        metrics = plot_errormap(model, dataset, ex=ex, iters=iters, thresh=thresh, 
                                do_plot=False, return_errormap=True, return_images=True)
        return metrics
    
    if examples is None:
        examples = [np.random.randint(len(dataset)) for _ in range(max_examples)]
    elif isinstance(examples, int):
        examples = [examples]
    else:
        examples = examples[:max_examples]
        
    titles = ['image1', 'gt', 'pred @ %d iters' % iters, 'iou = ']
    n_rows = min(len(examples), max_examples)
    n_cols = len(titles)
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(4*n_cols, 4*n_rows))
    if n_rows == 1:
        axes = [axes]
    
    for row, ex in enumerate(examples):
        return_vals = val_fn(ex)
        ax = axes[row]
        ax[0].imshow(return_vals['image1'])
        ax[1].imshow(return_vals['gt'])
        ax[2].imshow(return_vals['pred'])
        ax[3].imshow(return_vals['error_map'])
        
        iou = return_vals['iou']
        ts = titles[:3] + [titles[-1] + ("%.3f" % iou)]
        for col, title in enumerate(ts):
            if col == 3:
                ax[col].set_title(ts[col], fontsize=18, y=0.92)
            ax[col].set_xticks([])
            ax[col].set_yticks([])
        
    plt.tight_layout()
    plt.show()


def validate_examples(model, dataset, examples=[0], iters=24, thresh=4):
    
    def val_fn(ex):
        return plot_errormap(model, dataset, ex=ex, iters=iters, thresh=thresh, do_plot=False, return_errormap=False)
    
    if examples is None:
        examples = range(len(dataset))
    elif isinstance(examples, int):
        examples = [examples]
    
    metrics = {'iou': [], 'precision': [], 'recall': []}
    for ex in tqdm(examples):
        m = val_fn(ex)
        for k,v in m.items():
            metrics[k].append(v)
    return metrics

def agg_metrics(metrics):
    agg = {k:np.nanmean(np.array(v)) for k,v in metrics.items()}
    nans = {k+'_isnan':np.isnan(np.array(v)).mean() for k,v in metrics.items()}
    return (agg, nans)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(load_path)
# Out:
# ../checkpoints/raft-tdw-bn-allframes.pth
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset.is_test = False
tdw_dataset.max_start_frame = 5
visualize_error_maps(net, tdw_dataset, examples=[1,3,11,41,80], thresh=4)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = 5
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/raft-tdw-bn-allframes.pth
#   6%|▌         | 30/500 [00:08<02:09,  3.63it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<01:55,  3.84it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:15<00:00,  3.68it/s]
# ({'iou': 0.7764962111216519,
#   'precision': 0.8384561253722288,
#   'recall': 0.9122151587805122},
#  {'iou_isnan': 0.042, 'precision_isnan': 0.068, 'recall_isnan': 0.048})

# %%
print(load_path)
tdw_dataset.max_start_frame = None
tdw_dataset.is_test = True
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/raft-tdw-bn-allframes.pth
#   0%|          | 1/500 [00:00<02:00,  4.13it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:14<02:07,  3.48it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:11<00:00,  3.82it/s]
# ({'iou': 0.6240724749082448,
#   'precision': 0.8703083461953551,
#   'recall': 0.7079785642796534},
#  {'iou_isnan': 0.028, 'precision_isnan': 0.182, 'recall_isnan': 0.034})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = 5
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/raft-tdw-bn.pth
#   5%|▌         | 26/500 [00:07<02:15,  3.49it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<02:06,  3.50it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:14<00:00,  3.72it/s]
# ({'iou': 0.8258794803290415,
#   'precision': 0.9140077864749222,
#   'recall': 0.8990444173111047},
#  {'iou_isnan': 0.046, 'precision_isnan': 0.088, 'recall_isnan': 0.048})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = None
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/raft-tdw-bn.pth
#   0%|          | 1/500 [00:00<02:03,  4.05it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<02:16,  3.24it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:16<00:00,  3.66it/s]
# ({'iou': 0.5279725941740948,
#   'precision': 0.9000479561979515,
#   'recall': 0.5769562252348509},
#  {'iou_isnan': 0.03, 'precision_isnan': 0.308, 'recall_isnan': 0.032})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = 5
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../models/raft-sintel.pth
#   5%|▌         | 26/500 [00:07<02:04,  3.80it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<02:10,  3.38it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:15<00:00,  3.70it/s]
# ({'iou': 0.7969608048584764,
#   'precision': 0.9451550029757846,
#   'recall': 0.8369056144481988},
#  {'iou_isnan': 0.046, 'precision_isnan': 0.088, 'recall_isnan': 0.048})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = None
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../models/raft-sintel.pth
#   0%|          | 2/500 [00:00<02:12,  3.75it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<02:06,  3.49it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:27<00:00,  3.39it/s]
# ({'iou': 0.5751281585458882,
#   'precision': 0.9517182482523737,
#   'recall': 0.5998352226939102},
#  {'iou_isnan': 0.026, 'precision_isnan': 0.214, 'recall_isnan': 0.028})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = 5
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/135000_raft-tdw-bn-fullplay.pth
#   5%|▌         | 26/500 [00:07<02:12,  3.57it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<01:50,  4.01it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:15<00:00,  3.70it/s]
# ({'iou': 0.8250745329952744,
#   'precision': 0.9126674123845545,
#   'recall': 0.899859982067258},
#  {'iou_isnan': 0.042, 'precision_isnan': 0.084, 'recall_isnan': 0.048})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = None
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/135000_raft-tdw-bn-fullplay.pth
#   1%|▏         | 7/500 [00:01<02:23,  3.43it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:15<02:04,  3.55it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:15<00:00,  3.68it/s]
# ({'iou': 0.5716569099648304,
#   'precision': 0.9190602953628484,
#   'recall': 0.6162700945691229},
#  {'iou_isnan': 0.024, 'precision_isnan': 0.282, 'recall_isnan': 0.03})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = 5
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/75000_raft-tdw-bn-amaxtotalenergyframes.pth
#   6%|▌         | 30/500 [00:07<01:56,  4.03it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:14<01:54,  3.89it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:10<00:00,  3.83it/s]
# ({'iou': 0.8076026105179013,
#   'precision': 0.9060905814714588,
#   'recall': 0.8826501701323172},
#  {'iou_isnan': 0.044, 'precision_isnan': 0.08, 'recall_isnan': 0.048})

# %%
print(load_path)
tdw_dataset.is_test = True
tdw_dataset.max_start_frame = None
metrics = validate_examples(net, tdw_dataset, examples=None, thresh=0.5, iters=24)
agg_metrics(metrics)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/500 [00:00<?, ?it/s]
# ../checkpoints/75000_raft-tdw-bn-amaxtotalenergyframes.pth
#   0%|          | 2/500 [00:00<01:59,  4.17it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
#  11%|█▏        | 57/500 [00:14<01:52,  3.95it/s]/home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# 100%|██████████| 500/500 [02:10<00:00,  3.83it/s]
# ({'iou': 0.5184670331450768,
#   'precision': 0.904239446758588,
#   'recall': 0.5603282472279865},
#  {'iou_isnan': 0.026, 'precision_isnan': 0.318, 'recall_isnan': 0.03})

# %%
tdw_dataset.is_test = False
metrics = plot_errormap(net, tdw_dataset, ex=41, thresh=4, iters=24)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cmap = plt.cm.twilight(range(510))
cmap = np.stack([cmap]*64, 0)
plt.imshow(cmap)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
bootraft.layers.num_parameters(net.module.update_block)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3120960

# %%
print(net.module.update_block)
# Out:
# BasicUpdateBlock(
#   (encoder): BasicMotionEncoder(
#     (convc1): Conv2d(324, 256, kernel_size=(1, 1), stride=(1, 1))
#     (convc2): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (convf1): Conv2d(2, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (convf2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv): Conv2d(256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (gru): SepConvGRU(
#     (convz1): Conv2d(384, 128, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#     (convr1): Conv2d(384, 128, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#     (convq1): Conv2d(384, 128, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#     (convz2): Conv2d(384, 128, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#     (convr2): Conv2d(384, 128, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#     (convq2): Conv2d(384, 128, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#   )
#   (flow_head): FlowHead(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU(inplace=True)
#   )
#   (mask): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(256, 576, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
    root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
    dataset_names=['model_split_4'],    
    split='training',
    filepattern="*",
    test_filepattern="0*[0-4]",
    min_start_frame=0,
    max_start_frame=None,
    scale_to_pixels=True,
    get_gt_flow=True,
    training_frames='../datasets/supervision_frames/model_split_4_threshargmax.json',
    testing_frames='../datasets/supervision_frames/model_split_4_threshargmax.json'
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)
# Out:
# 1250
# False
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
list(tdw_dataset.training_frames.values())[:10]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [[4], [9], [14], [21], [11], [4], [48], [15], [11], [52]]

# %%
list(tdw_dataset.testing_frames.values())[:10]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [[4], [9], [14], [21], [11], [44], [7], [14], [119], [6]]

# %%
data_blob = tdw_dataset[5]
# Out:
# selected frame 4
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
torch.randint?
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
x = torch.rand([4, 8, 64]).transpose(1,2)
inds = torch.randint(low=0, high=64, size=[4,6], dtype=torch.long)
b_inds = torch.arange(4, dtype=torch.long)[:,None].repeat(1,6)
inds = torch.stack([b_inds, inds])
x[list(inds)].shape
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# torch.Size([4, 6, 8])

# %%
import kmeans
Knet = kmeans.KMeans(num_clusters=32, num_iters=50, append_coordinates=True).cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
img1, img2, flow, _ = tdw_dataset[3]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
img = img1[None].to(torch.uint8).cuda()
labels = Knet(img)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
viz(img)
plt.show()
viz(labels)
plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import compute_training_frames as filtering
knet = torch.nn.DataParallel(filtering.KMeans(16, 50, True)).cuda()
seg_net = filtering.VideoSegmentationModel(model=knet, num_input_frames=1).cuda()
motion_net = net
explain_net = filtering.ExplainedAwayMotion(motion_net, seg_net)

def viz_segments(net, dataset, ex=0, iters=12, test_mode=True):
    img1, img2 = dataset[ex][:2]
    score = net(img1[None].cuda(), img2[None].cuda(), iters=iters, test_mode=True)
    
    fig, axes = plt.subplots(1,4, figsize=(12,4))
    
    axes[0].imshow((img1 / 255.).permute(1,2,0).numpy())
    axes[1].imshow(net.motion_segments[0].detach().cpu().numpy(), cmap='magma')
    axes[2].imshow(net.static_segments[0].detach().cpu().numpy(), cmap='plasma')
    axes[3].imshow(net.out_segments[0].detach().cpu().numpy(), cmap='YlGnBu')
    
    titles = ['Image1', 'MotionSeg', 'StaticSegs', 'FinalSegs']
    for i,ax in enumerate(axes):
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(titles[i], fontsize=20)
        
    plt.tight_layout()
    plt.show()
    
    return score
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
viz_segments(explain_net, tdw_dataset, ex=41)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # read in robonet

# %%
import dorsalventral.data.robonet as robonet
import dorsalventral.vis_utils as vis_utils
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
robonet.get_robot_names()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['berkeley_sawyer',
#  'berkeley_widowx',
#  'google',
#  'penn_baxter_left',
#  'penn_baxter_right',
#  'penn_kuka',
#  'stanford_fetch',
#  'stanford_franka',
#  'stanford_franka_corr_noise']

# %%
robonet_dataset = robonet.RobonetDataset(sequence_length=2)
# Out:
# Using 700 files from robots with names ['berkeley_sawyer', 'berkeley_widowx', 'google', 'penn_baxter_left', 'penn_baxter_right', 'penn_kuka', 'stanford_fetch', 'stanford_franka', 'stanford_franka_corr_noise']
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rmov = robonet_dataset[0]
# Out:
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj11308.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(rmov['images'], None, 1)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
robonet_dataset = raft_datasets.RobonetFlowDataset(sequence_length=2, dataset_names='berkeley*')
print(robonet_dataset.all_robots)
# Out:
# Using 200 files from robots with names ['berkeley*']
# ['berkeley_sawyer', 'berkeley_widowx', 'google', 'meta_data.pkl', 'penn_baxter_left', 'penn_baxter_right', 'penn_kuka', 'stanford_fetch', 'stanford_franka', 'stanford_franka_corr_noise']
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
img1, img2 = robonet_dataset[3]
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj15183.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)

# %%
viz_segments(explain_net, robonet_dataset, 15)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj19970.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# 0.2557421922683716

# %%
visualize_error_maps(net, robonet_dataset, examples=None, thresh=0.5)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj43817.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in double_scalars
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj38431.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj19815.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj62924.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)
# filename: /data5/dbear/robonet_sampler/hdf5/berkeley_sawyer_traj8560.hdf5
# num_states --> 31
# arr shape (2, 240, 320, 3)

# %%
robonet_dataset.files
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['/data5/dbear/robonet_sampler/hdf5/google_traj10249.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj10293.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj10880.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj11326.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj11340.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj11341.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj11496.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj12025.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj12263.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj12696.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj12847.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj12854.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj13822.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj14207.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj14950.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj15342.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj1647.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj16737.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj17672.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj19297.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj2009.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj21336.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj21737.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj21921.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj21925.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj2222.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj22752.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj23741.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj24105.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj2472.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj25128.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj25158.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj25337.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj25435.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj26258.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj26849.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj26970.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj2784.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj27933.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj28211.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj28953.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj29021.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj29039.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj29419.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj30196.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj3034.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj32201.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj32406.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj32646.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj33357.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj33440.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj33580.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj34361.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj34539.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj34872.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj350.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj35895.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj36256.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj3642.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj36539.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj37369.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj38647.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj38862.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj39427.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj40227.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj40470.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj40472.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj41950.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj41957.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj42309.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj43558.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj44232.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj45786.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj47722.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj47888.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj48293.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj49516.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj49593.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj49806.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj49962.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj50612.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj51213.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj52459.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj53495.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj55544.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj55707.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj55939.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj56048.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj56614.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj5793.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj6085.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj6556.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj7157.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj7200.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj7899.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj8419.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj8458.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj9416.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj9669.hdf5',
#  '/data5/dbear/robonet_sampler/hdf5/google_traj9699.hdf5']
