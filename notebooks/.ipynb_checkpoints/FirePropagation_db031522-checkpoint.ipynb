# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '8'

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms

import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
sys.path.append('../core')

from raft import RAFT
from train import get_args, load_model, IsMovingTarget
import datasets as raft_datasets
import utils.flow_viz as flow_viz

def set_args(args_dict={}):
    args = get_args("")
    for k,v in args_dict.items():
        args.__setattr__(k, v)
    return args

def tensor_to_arr(tensor, ex=0):
    if len(tensor.shape) == 4:
        tensor = tensor[ex]
    return tensor.detach().permute(1, 2, 0).cpu().numpy()

def viz(tensor, ex=0):
    im = tensor_to_arr(tensor, ex)
    if im.max() > 2.0:
        im = im / 255.0
    plt.imshow(im)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:696: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   collections.MutableMapping.register(ParseResults)
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:2273: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   elif isinstance( exprs, collections.Sequence ):
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:568: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.object, string),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:569: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.bool, bool),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:593: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:597: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:614: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING_REF: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:619: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL_REF: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:100: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object: SlowAppendObjectArrayToTensorProto,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:101: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool: SlowAppendBoolArrayToTensorProto,

# %% [markdown]
# ## Now train on the larger dataset

# %%
import dorsalventral.models.targets as targets
import dorsalventral.vis_utils as vis_utils
import dorsalventral.models.fire_propagation as fprop
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
    root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
#     root='/mnt/fs5/dbear/tdw_datasets/playroom_large_v3/',
    dataset_names=['model_split_4'],    
#     dataset_names=['model_split_%d' % split for split in range(4)],
    split='training',
    filepattern="0041",
#     test_filepattern="0*[0-4]",
    test_filepattern="*9",
    min_start_frame=6,
    max_start_frame=6,
    scale_to_pixels=True,
    get_gt_flow=True,
    get_backward_frame=True
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)
# Out:
# 1
# False
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
motion_path = '../checkpoints/35000_motion-rnd0-tdw-bs8-small-fullplay-tr0-8.pth'

# mclass_teacher = load_model(
#                    motion_path,
#                    small=False, 
#                    cuda=True, 
#                    train=False)


mprop_student = load_model(None, 
                           model_class='prop', 
                           motion_ckpt=motion_path,
                   small=True, 
                   cuda=True, 
                   train=True, 
                   num_sample_points=128,
                   affinity_nonlinearity='sigmoid',
                   motion_thresh=0.25,
                   target_thresh=0.1,        
                   binarize_motion=True,
                   num_propagation_iters=5,
                   predict_every=1,
                   affinity_radius=5,
                   affinity_radius_inference=None,
                   static_affinities=True)


IM = targets.IsMovingTarget(warp_radius=3, 
                            thresh=None, 
                            normalize_error=False, 
                            normalize_features=False).cuda()



raft_iters=12
loss_fn = nn.BCELoss(reduction='none')
target_thresh = 0.1
opt = torch.optim.Adam(mprop_student.parameters(), lr=0.0001)


def get_motion_target(img0, img1, img2, thresh=0.01):
    video = torch.stack([img0, img1, img2], 1).float() / 255.
    target = (IM(video)[:,0] > thresh).float()
    return target

def get_teacher_target(teacher, img0, img1, img2, thresh=0.25):
    motion_fwd = teacher(img1, img2, test_mode=False, iters=raft_iters)[-1]
#     motion_bck = teacher(img1, img0, test_mode=False, iters=raft_iters)[0]
    target = (torch.sigmoid(motion_fwd).detach() > thresh).float()
    return target

def train_step(data, model, optimizer, teacher=None, thresh=0.01, motion_scale=1.0, affinity_scale=1.0):
    
    optimizer.zero_grad()
    img1, img2, img0 = [d.cuda() for d in data[:3]]
    if teacher is None:
        target = get_motion_target(img0, img1, img2, thresh=thresh)
#         target = get_teacher_target(teacher, img0, img1, img2, thresh=thresh)
#     else:
#         target = get_teacher_target(teacher, img0, img1, img2, thresh=thresh)
    preds_list = model(img1, img2, test_mode=False, iters=raft_iters)
    
    if teacher is None:
        loss_list = [loss_fn(torch.sigmoid(pred), target).mean() for pred in preds_list]
        loss = motion_scale * (sum(loss_list) / len(loss_list))
    else:
#         loss_list = [loss_fn(pred.clamp(max=1.), target).mean() for pred in preds_list]
#         loss = motion_scale * loss_list[0] + affinity_scale * (sum(loss_list[1:]) / len(loss_list[1:]))
        loss_list = model.module.propagator.loss_list
        loss = affinity_scale * (sum(loss_list) / len(loss_list))
    loss.backward()
    optimizer.step()
    
    if teacher is not None:
        target = model.module.propagator.target
    
    return (preds_list, target, loss, loss_list)

def val_step(data, model, test_mode=True, motion_thresh=None):
    
    img1, img2, img0 = [d[None].cuda() for d in data[:3]]
    target = get_motion_target(img0, img1, img2, thresh=target_thresh)
    if motion_thresh is not None:
        model.module.propagator.thresh = motion_thresh
    preds = model(img1, img2, test_mode=test_mode, iters=raft_iters)
    return (preds, target)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# motion model <All keys matched successfully>

# %%
num_epochs = 50
num_steps = None
print_every = 10

rnd = 1

if rnd == 0:
    m_scale = 100.0
    a_scale = 0.
    teacher = None
    student = mclass_teacher
    target_thresh = 0.01
elif rnd == 1:
    m_scale = 0.
    a_scale = 1.
    teacher = mprop_student.module.motion_model
    student = mprop_student
    target_thresh = 0.1

batch_size = 1
trainloader = torch.utils.data.DataLoader(tdw_dataset, 
                                          batch_size=batch_size,
                                          shuffle=True,
                                          pin_memory=False,
                                          num_workers=4,
                                          drop_last=True)

for epoch in range(num_epochs):
    for step, data in enumerate(trainloader):
        if step == num_steps:
            break
        
        preds_list, target, loss, loss_list = train_step(data=data, model=student, optimizer=opt, teacher=teacher,
                                             thresh=target_thresh,
                                             motion_scale=m_scale, affinity_scale=a_scale)
        if (step % print_every) == 0:
            print("epoch %d / step %d ---- loss first %.3f ---- loss last %.3f ---- loss total %.3f" % 
                  (epoch, step, loss_list[0].item(), loss_list[-1].item(), loss.item()))
            
    if step == num_steps:
        break
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# epoch 0 / step 0 ---- loss first 0.602 ---- loss last 6.594 ---- loss total 5.296
# epoch 1 / step 0 ---- loss first 0.804 ---- loss last 5.337 ---- loss total 3.631
# epoch 2 / step 0 ---- loss first 0.744 ---- loss last 4.042 ---- loss total 2.782
# epoch 3 / step 0 ---- loss first 1.025 ---- loss last 1.933 ---- loss total 2.604
# epoch 4 / step 0 ---- loss first 1.091 ---- loss last 2.488 ---- loss total 2.150
# epoch 5 / step 0 ---- loss first 0.845 ---- loss last 1.545 ---- loss total 1.504
# epoch 6 / step 0 ---- loss first 0.990 ---- loss last 1.642 ---- loss total 1.447
# epoch 7 / step 0 ---- loss first 0.699 ---- loss last 1.284 ---- loss total 1.144
# epoch 8 / step 0 ---- loss first 0.707 ---- loss last 0.887 ---- loss total 1.467
# epoch 9 / step 0 ---- loss first 0.775 ---- loss last 1.363 ---- loss total 1.182
# epoch 10 / step 0 ---- loss first 0.633 ---- loss last 1.067 ---- loss total 1.121
# epoch 11 / step 0 ---- loss first 0.667 ---- loss last 1.027 ---- loss total 1.170
# epoch 12 / step 0 ---- loss first 0.956 ---- loss last 0.951 ---- loss total 1.468
# epoch 13 / step 0 ---- loss first 0.705 ---- loss last 0.845 ---- loss total 1.289
# epoch 14 / step 0 ---- loss first 0.658 ---- loss last 0.705 ---- loss total 0.915
# epoch 15 / step 0 ---- loss first 1.167 ---- loss last 1.158 ---- loss total 1.256
# epoch 16 / step 0 ---- loss first 0.630 ---- loss last 0.687 ---- loss total 0.783
# epoch 17 / step 0 ---- loss first 0.543 ---- loss last 0.474 ---- loss total 0.648
# epoch 18 / step 0 ---- loss first 0.751 ---- loss last 1.205 ---- loss total 1.068
# epoch 19 / step 0 ---- loss first 0.537 ---- loss last 0.807 ---- loss total 1.196
# epoch 20 / step 0 ---- loss first 0.516 ---- loss last 0.842 ---- loss total 1.366
# epoch 21 / step 0 ---- loss first 0.666 ---- loss last 0.603 ---- loss total 1.144
# epoch 22 / step 0 ---- loss first 1.057 ---- loss last 0.867 ---- loss total 1.199
# epoch 23 / step 0 ---- loss first 0.527 ---- loss last 0.328 ---- loss total 0.842
# epoch 24 / step 0 ---- loss first 0.569 ---- loss last 0.556 ---- loss total 0.843
# epoch 25 / step 0 ---- loss first 0.483 ---- loss last 0.566 ---- loss total 0.822
# epoch 26 / step 0 ---- loss first 0.435 ---- loss last 0.505 ---- loss total 0.719
# epoch 27 / step 0 ---- loss first 0.437 ---- loss last 0.374 ---- loss total 0.664
# epoch 28 / step 0 ---- loss first 0.527 ---- loss last 0.689 ---- loss total 0.904
# epoch 29 / step 0 ---- loss first 0.572 ---- loss last 0.483 ---- loss total 0.664
# epoch 30 / step 0 ---- loss first 0.655 ---- loss last 0.785 ---- loss total 0.755
# epoch 31 / step 0 ---- loss first 0.580 ---- loss last 0.480 ---- loss total 0.799
# epoch 32 / step 0 ---- loss first 0.275 ---- loss last 0.315 ---- loss total 0.584
# epoch 33 / step 0 ---- loss first 0.475 ---- loss last 0.392 ---- loss total 0.554
# epoch 34 / step 0 ---- loss first 0.308 ---- loss last 0.707 ---- loss total 0.613
# epoch 35 / step 0 ---- loss first 0.302 ---- loss last 0.303 ---- loss total 0.648
# epoch 36 / step 0 ---- loss first 0.359 ---- loss last 0.625 ---- loss total 0.648
# epoch 37 / step 0 ---- loss first 0.283 ---- loss last 0.531 ---- loss total 0.443
# epoch 38 / step 0 ---- loss first 0.552 ---- loss last 0.315 ---- loss total 0.648
# epoch 39 / step 0 ---- loss first 0.550 ---- loss last 0.526 ---- loss total 0.704
# epoch 40 / step 0 ---- loss first 0.519 ---- loss last 0.341 ---- loss total 0.557
# epoch 41 / step 0 ---- loss first 0.550 ---- loss last 0.350 ---- loss total 0.708
# epoch 42 / step 0 ---- loss first 0.540 ---- loss last 0.352 ---- loss total 0.666
# epoch 43 / step 0 ---- loss first 0.625 ---- loss last 0.257 ---- loss total 0.755
# epoch 44 / step 0 ---- loss first 0.427 ---- loss last 0.563 ---- loss total 0.760
# epoch 45 / step 0 ---- loss first 0.230 ---- loss last 0.321 ---- loss total 0.432
# epoch 46 / step 0 ---- loss first 0.250 ---- loss last 0.366 ---- loss total 0.470
# epoch 47 / step 0 ---- loss first 0.333 ---- loss last 0.368 ---- loss total 0.515
# epoch 48 / step 0 ---- loss first 0.456 ---- loss last 0.752 ---- loss total 0.638
# epoch 49 / step 0 ---- loss first 0.336 ---- loss last 0.443 ---- loss total 0.469

# %%
vis_utils.imshow(mprop_student.module.propagator.target)
vis_utils.imshow(mprop_student.module.propagator.loss_mask)
vis_utils.imshow(preds_list[0])
vis_utils.imshow(preds_list[-1])
vis_utils.imshow(nn.BCELoss(reduction='none')(preds_list[1], target) * mprop_student.module.propagator.loss_mask)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# save_path = '../checkpoints/prop_split4_sigmoid_ep30.pth'
# saved = torch.save(mprop_student.state_dict(), save_path)
# did_load = mprop_student.load_state_dict(torch.load(save_path), strict=False)
# print(did_load)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ex = 0
mprop_student.eval()
mprop_student.module.propagator.num_iters = 1
mprop_student.module.propagator.r = 1
mprop_student.module.propagator.k = 3
mprop_student.module.propagator.K = 9

teacher_preds, target = val_step(tdw_dataset[ex], mprop_student.module.motion_model,
                                 test_mode=True, motion_thresh=None)
preds, target = val_step(tdw_dataset[ex], mprop_student, test_mode=True, motion_thresh=0.25)
len(preds)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3

# %%
# vis_utils.imshow(torch.sigmoid(teacher_preds[-1]), cmap='magma', vmin=0, vmax=1)
vis_utils.imshow(torch.sigmoid(teacher_preds[-1]) < 0.01, cmap='magma', vmin=0, vmax=1)
vis_utils.imshow(torch.sigmoid(teacher_preds[-1]) > 0.25, cmap='magma', vmin=0, vmax=1)

vis_utils.imshow(preds[-1], cmap='twilight', vmin=0, vmax=2)
vis_utils.imshow(preds[-2], cmap='inferno', vmin=0, vmax=preds[-2].amax() * 1.3)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
a = preds[0][0,:,250,400].sigmoid()
a = a / a.max(0)[0]
plt.plot(a.detach().cpu().numpy())
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def vis_local_affinities(affinities, node=[250,400]):
    aff_node = affinities[:,:,node[0],node[1]]

    A = torch.zeros_like(affinities)
    A[:,:,node[0],node[1]] = aff_node
    K = aff_node.shape[-1] // 2
    aff_node = torch.cat([A[:,:K], torch.zeros_like(A[:,:1]), A[:,K:]], 1)    
    effects = fprop.compute_local_effects(torch.ones_like(affinities[:,:1]), aff_node)
    return effects
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
conf_target = mprop_student.module.propagator._compute_confident_targets(
    teacher_preds[-1], nonlinearity=torch.sigmoid)
torch.where(conf_target == 1)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:0'),
#  tensor([  0,   0,   0,  ..., 120, 120, 120], device='cuda:0'),
#  tensor([185, 185, 186,  ..., 459, 460, 460], device='cuda:0'),
#  tensor([398, 399, 399,  ..., 373, 371, 372], device='cuda:0'))

# %%
K = (conf_target.shape[1] - 1) // 2
local = vis_local_affinities(torch.cat([conf_target[:,:K], conf_target[:,K+1:]], 1).float(), node=[185,398])
vis_utils.imshow(local[:,:,175:195,390:410])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vmin, vmax = teacher_preds[-1].amin(), teacher_preds[-1].amax()
target = teacher_preds[-1]
p_thresh, n_thresh = 0.4, 0.1
fig, axes = plt.subplots(1,3, figsize=(12,4))
vis_utils.imshow(target, axes[0], cmap='magma', vmin=vmin, vmax=vmax)
vis_utils.imshow(torch.sigmoid(target) > p_thresh, axes[1], cmap='magma', vmin=0, vmax=1)
vis_utils.imshow(torch.sigmoid(target) < n_thresh, axes[2], cmap='magma', vmin=0, vmax=1)

titles = ['motion logits', 'probs > %.2f' % p_thresh, 'probs < %.2f' % n_thresh]
for i, ax in enumerate(axes):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(titles[i], fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
torch.logical_not?
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Change loss so that high confidence samples from teacher must propagate

# %%
Sampler = fprop.MotionEnergySampler(1, thresh=None, binarize=True, to_nodes=False).cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(torch.sigmoid(teacher_preds[-1]))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Sampler.binarize = True
samples, energy = Sampler(
    torch.sigmoid(teacher_preds[-1][:,None]),
    num_points=32,
    compute_delta_energy=False,
    eps=0.5
)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(samples[0,...], cmap='magma', vmin=0., vmax=0.1)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
FP = fprop.FirePropagation(
    thresh=0.5,
    num_sample_points=32,
    num_iters=50,
    predict_every=5
).cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
zeros = torch.cat([torch.ones_like(teacher_preds[-1])]*4, -3)
x = teacher_preds[-1]
A = torch.cat([zeros, zeros], -3)
motion, fire, preds_list = FP(x, A)
print(len(preds_list))
# Out:
# 12
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(preds_list[5], cmap='magma', vmin=0, vmax=1)
vis_utils.imshow(motion, cmap='magma', vmin=0, vmax=1)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-2837694a2ec1> in <module>
# ----> 1 vis_utils.imshow(preds_list[5], cmap='magma', vmin=0, vmax=1)
#       2 vis_utils.imshow(motion, cmap='magma', vmin=0, vmax=1)
#
# IndexError: list index out of range

# %%
torch.unique(preds_list[-1])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor([0., 1.], device='cuda:0', grad_fn=<Unique2Backward>)
