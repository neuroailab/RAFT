# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '8'

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms

import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
sys.path.append('../core')

from raft import RAFT
from train import get_args, load_model, IsMovingTarget
import datasets as raft_datasets
import utils.flow_viz as flow_viz

def set_args(args_dict={}):
    args = get_args("")
    for k,v in args_dict.items():
        args.__setattr__(k, v)
    return args

def tensor_to_arr(tensor, ex=0):
    if len(tensor.shape) == 4:
        tensor = tensor[ex]
    return tensor.detach().permute(1, 2, 0).cpu().numpy()

def viz(tensor, ex=0):
    im = tensor_to_arr(tensor, ex)
    if im.max() > 2.0:
        im = im / 255.0
    plt.imshow(im)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:696: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   collections.MutableMapping.register(ParseResults)
# /home/dbear/tenv/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py:2273: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   elif isinstance( exprs, collections.Sequence ):
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:568: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.object, string),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:569: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (np.bool, bool),
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:593: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:597: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:614: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_STRING_REF: np.object,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:619: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   types_pb2.DT_BOOL_REF: np.bool,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:100: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.object: SlowAppendObjectArrayToTensorProto,
# /home/dbear/tenv/lib/python3.7/site-packages/tensorboard/util/tensor_util.py:101: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.bool: SlowAppendBoolArrayToTensorProto,

# %% [markdown]
# ## Load a motion model and dataset

# %%
# motion_net = load_model('../checkpoints/20000_motion-tdw-bs8-small-fullplay-tr0-8.pth',
#                  train=False, cuda=True, freeze_bn=False, small=True, gpus=[0])
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
    root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
#     root='/mnt/fs5/dbear/tdw_datasets/playroom_large_v3/',
    dataset_names=['model_split_4'],    
#     dataset_names=['model_split_%d' % split for split in range(4)],
    split='training',
    filepattern="*",
#     test_filepattern="0*[0-4]",
    test_filepattern="*9",
    min_start_frame=6,
    max_start_frame=6,
    scale_to_pixels=True,
    get_gt_flow=True,
    get_backward_frame=True
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)
# Out:
# 1250
# False
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Create a training target for motion

# %%
import dorsalventral.models.targets as targets
import dorsalventral.vis_utils as vis_utils
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
IM = targets.IsMovingTarget(3, thresh=None, normalize_error=False, normalize_features=False).cuda()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ex = 41
img1, img2, img0 = tdw_dataset[ex][:3]
x = torch.stack([img0, img1, img2], 0).float() / 255.
target = IM(x[None].cuda())
# _, pred = motion_net(img1[None].cuda(), img2[None].cuda(), test_mode=True, iters=12)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mean = F.relu(target[0]).mean(dim=(-2,-1), keepdim=True)
vis_utils.imshow((F.relu(target[0]) - mean) / mean, vmin=0, vmax=1.0)
vis_utils.imshow(F.relu(target[0]), vmin=0, vmax=0.025)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
target[0].mean()
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor(0.0007, device='cuda:0')

# %% [markdown]
# # Train

# %%
mprop = load_model(None, model_class='prop', 
                   small=False, 
                   cuda=True, 
                   train=True, 
                   num_sample_points=2048,
                   affinity_nonlinearity='softmax',
                   motion_thresh=0.25,
                   binarize_motion=True,
                   num_propagation_iters=50)

def get_motion_target(t):
    t = F.relu(t)
    mean = t.mean((-2,-1), True).clamp(min=1e-9)
    return F.relu((t - mean) / mean)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
num_steps = 100
print_every = 1
raft_iters = 12
scale = 100.0
optim = torch.optim.Adam(mprop.parameters(), lr=0.0001)
loss_fn = nn.BCELoss(reduction='none')
motion_thresh = 0.01

ex = 41
img1, img2, img0 = tdw_dataset[ex][:3]
x = torch.stack([img0, img1, img2], 0).float() / 255.
target = IM(x[None].cuda())

# motion_target = (get_motion_target(target[0]) > motion_thresh).float()
motion_target = (target[0] > motion_thresh).float()


x1, x2 = img1[None].cuda(), img2[None].cuda()

train_loss = []
for step in range(num_steps+1):
    
    optim.zero_grad()
    preds_list = mprop(x1, x2, test_mode=False, iters=raft_iters)
    loss_list = [scale * loss_fn(pred.clamp(max=1.), motion_target).mean() for pred in preds_list]
    loss = sum(loss_list)
    loss.backward()
    optim.step()
    
    train_loss.append(loss.item())
    if (step % print_every) == 0:
        print("step: %d, loss_first, loss_last, loss_total ---- %.3f, %.3f, %.3f" % 
              (step, loss_list[0].item(), loss_list[-1].item(), loss.item()))
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# step: 0, loss_first, loss_last, loss_total ---- 46.634, 272.009, 3042.275
# step: 1, loss_first, loss_last, loss_total ---- 18.685, 273.666, 3029.015
# step: 2, loss_first, loss_last, loss_total ---- 19.368, 273.666, 3029.699
# step: 3, loss_first, loss_last, loss_total ---- 18.466, 273.666, 3028.797
# step: 4, loss_first, loss_last, loss_total ---- 15.917, 273.666, 3026.248
# step: 5, loss_first, loss_last, loss_total ---- 13.152, 273.666, 3023.483
# step: 6, loss_first, loss_last, loss_total ---- 12.578, 273.666, 3022.909
# step: 7, loss_first, loss_last, loss_total ---- 12.693, 273.666, 3023.023
# step: 8, loss_first, loss_last, loss_total ---- 10.706, 273.666, 3021.036
# step: 9, loss_first, loss_last, loss_total ---- 10.262, 273.666, 3020.593
# step: 10, loss_first, loss_last, loss_total ---- 10.112, 273.666, 3020.443
# step: 11, loss_first, loss_last, loss_total ---- 9.243, 273.666, 3019.573
# step: 12, loss_first, loss_last, loss_total ---- 8.170, 273.666, 3018.500
# step: 13, loss_first, loss_last, loss_total ---- 7.801, 198.227, 2373.407
# step: 14, loss_first, loss_last, loss_total ---- 7.790, 189.482, 2197.649
# step: 15, loss_first, loss_last, loss_total ---- 7.328, 178.178, 2148.474
# step: 16, loss_first, loss_last, loss_total ---- 6.937, 179.611, 2265.799
# step: 17, loss_first, loss_last, loss_total ---- 7.027, 188.020, 2387.222
# step: 18, loss_first, loss_last, loss_total ---- 7.049, 195.158, 2445.529
# step: 19, loss_first, loss_last, loss_total ---- 6.720, 194.688, 2414.003
# step: 20, loss_first, loss_last, loss_total ---- 6.470, 187.181, 2287.596
# step: 21, loss_first, loss_last, loss_total ---- 6.523, 166.617, 1896.159
# step: 22, loss_first, loss_last, loss_total ---- 6.587, 168.366, 1856.444
# step: 23, loss_first, loss_last, loss_total ---- 6.442, 175.858, 1898.083
# step: 24, loss_first, loss_last, loss_total ---- 6.262, 171.304, 1949.376
# step: 25, loss_first, loss_last, loss_total ---- 6.224, 182.751, 2270.751
# step: 26, loss_first, loss_last, loss_total ---- 6.242, 188.866, 2353.750
# step: 27, loss_first, loss_last, loss_total ---- 6.142, 191.986, 2390.998
# step: 28, loss_first, loss_last, loss_total ---- 5.980, 186.195, 2337.476
# step: 29, loss_first, loss_last, loss_total ---- 5.913, 170.349, 2190.833
# step: 30, loss_first, loss_last, loss_total ---- 5.911, 170.181, 2007.961
# step: 31, loss_first, loss_last, loss_total ---- 5.881, 170.097, 2042.692
# step: 32, loss_first, loss_last, loss_total ---- 5.825, 169.695, 2286.203
# step: 33, loss_first, loss_last, loss_total ---- 5.795, 192.785, 2523.470
# step: 34, loss_first, loss_last, loss_total ---- 5.786, 212.427, 2697.205
# step: 35, loss_first, loss_last, loss_total ---- 5.747, 211.773, 2683.933
# step: 36, loss_first, loss_last, loss_total ---- 5.689, 194.869, 2536.443
# step: 37, loss_first, loss_last, loss_total ---- 5.653, 188.042, 2420.738
# step: 38, loss_first, loss_last, loss_total ---- 5.633, 172.233, 2074.642
# step: 39, loss_first, loss_last, loss_total ---- 5.598, 178.435, 2034.733
# step: 40, loss_first, loss_last, loss_total ---- 5.564, 170.646, 2036.567
# step: 41, loss_first, loss_last, loss_total ---- 5.553, 167.955, 2059.024
# step: 42, loss_first, loss_last, loss_total ---- 5.515, 171.762, 2008.973
# step: 43, loss_first, loss_last, loss_total ---- 5.492, 169.457, 1983.083
# step: 44, loss_first, loss_last, loss_total ---- 5.476, 169.280, 1976.737
# step: 45, loss_first, loss_last, loss_total ---- 5.441, 172.098, 1983.770
# step: 46, loss_first, loss_last, loss_total ---- 5.425, 171.822, 2008.911
# step: 47, loss_first, loss_last, loss_total ---- 5.406, 170.183, 1999.832
# step: 48, loss_first, loss_last, loss_total ---- 5.384, 168.372, 1977.006
# step: 49, loss_first, loss_last, loss_total ---- 5.372, 171.392, 1981.518
# step: 50, loss_first, loss_last, loss_total ---- 5.346, 172.517, 1975.536
# step: 51, loss_first, loss_last, loss_total ---- 5.338, 173.232, 1981.121
# step: 52, loss_first, loss_last, loss_total ---- 5.314, 171.409, 1966.215
# step: 53, loss_first, loss_last, loss_total ---- 5.305, 175.081, 1969.055
# step: 54, loss_first, loss_last, loss_total ---- 5.284, 169.924, 1977.955
# step: 55, loss_first, loss_last, loss_total ---- 5.278, 172.749, 2001.536
# step: 56, loss_first, loss_last, loss_total ---- 5.260, 168.380, 2001.017
# step: 57, loss_first, loss_last, loss_total ---- 5.254, 169.983, 1965.133
# step: 58, loss_first, loss_last, loss_total ---- 5.236, 173.632, 2001.979
# step: 59, loss_first, loss_last, loss_total ---- 5.228, 167.374, 2004.480
# step: 60, loss_first, loss_last, loss_total ---- 5.215, 175.017, 1996.115
# step: 61, loss_first, loss_last, loss_total ---- 5.206, 170.044, 1985.998
# step: 62, loss_first, loss_last, loss_total ---- 5.196, 173.493, 1999.102
# step: 63, loss_first, loss_last, loss_total ---- 5.182, 173.044, 2001.062
# step: 64, loss_first, loss_last, loss_total ---- 5.176, 172.438, 1970.531
# step: 65, loss_first, loss_last, loss_total ---- 5.164, 172.431, 2002.770
# step: 66, loss_first, loss_last, loss_total ---- 5.155, 171.662, 2006.378
# step: 67, loss_first, loss_last, loss_total ---- 5.149, 175.398, 1952.649
# step: 68, loss_first, loss_last, loss_total ---- 5.138, 167.933, 1979.149
# step: 69, loss_first, loss_last, loss_total ---- 5.129, 169.600, 1972.502
# step: 70, loss_first, loss_last, loss_total ---- 5.122, 168.959, 1940.214
# step: 71, loss_first, loss_last, loss_total ---- 5.115, 171.553, 2006.507
# step: 72, loss_first, loss_last, loss_total ---- 5.107, 173.231, 1938.305
# step: 73, loss_first, loss_last, loss_total ---- 5.098, 169.104, 1991.891
# step: 74, loss_first, loss_last, loss_total ---- 5.089, 171.560, 1948.084
# step: 75, loss_first, loss_last, loss_total ---- 5.082, 169.440, 1956.380
# step: 76, loss_first, loss_last, loss_total ---- 5.078, 164.988, 1972.536
# step: 77, loss_first, loss_last, loss_total ---- 5.075, 167.810, 1888.145
# step: 78, loss_first, loss_last, loss_total ---- 5.072, 169.248, 1989.565
# step: 79, loss_first, loss_last, loss_total ---- 5.070, 165.727, 1877.145
# step: 80, loss_first, loss_last, loss_total ---- 5.054, 165.713, 1971.101
# step: 81, loss_first, loss_last, loss_total ---- 5.041, 165.974, 1873.928
# step: 82, loss_first, loss_last, loss_total ---- 5.034, 165.832, 1882.960
# step: 83, loss_first, loss_last, loss_total ---- 5.034, 163.341, 1962.494
# step: 84, loss_first, loss_last, loss_total ---- 5.032, 171.009, 1861.673
# step: 85, loss_first, loss_last, loss_total ---- 5.017, 159.448, 1916.409
# step: 86, loss_first, loss_last, loss_total ---- 5.006, 163.348, 1871.342
# step: 87, loss_first, loss_last, loss_total ---- 5.002, 164.539, 1858.811
# step: 88, loss_first, loss_last, loss_total ---- 5.001, 160.800, 1921.991
# step: 89, loss_first, loss_last, loss_total ---- 4.997, 161.216, 1838.693
# step: 90, loss_first, loss_last, loss_total ---- 4.983, 158.958, 1903.476
# step: 91, loss_first, loss_last, loss_total ---- 4.972, 158.012, 1836.040
# step: 92, loss_first, loss_last, loss_total ---- 4.965, 155.943, 1836.247
# step: 93, loss_first, loss_last, loss_total ---- 4.961, 156.291, 1860.973
# step: 94, loss_first, loss_last, loss_total ---- 4.956, 158.987, 1828.770
# step: 95, loss_first, loss_last, loss_total ---- 4.948, 156.823, 1865.668
# step: 96, loss_first, loss_last, loss_total ---- 4.941, 157.655, 1820.784
# step: 97, loss_first, loss_last, loss_total ---- 4.933, 156.769, 1843.344
# step: 98, loss_first, loss_last, loss_total ---- 4.927, 160.462, 1812.568
# step: 99, loss_first, loss_last, loss_total ---- 4.919, 153.291, 1857.171
# step: 100, loss_first, loss_last, loss_total ---- 4.916, 157.077, 1804.638

# %%
vis_utils.imshow(preds_list[0])
vis_utils.imshow(preds_list[-1])
vis_utils.imshow(motion_target)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mprop.module.propagator.thresh = 0.25
fire, motion = mprop(x1, x2, test_mode=True)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(motion)
vis_utils.imshow(fire, cmap='twilight', vmin=0, vmax=50)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Now train on the larger dataset

# %%
import dorsalventral.models.targets as targets
import dorsalventral.vis_utils as vis_utils
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tdw_dataset = raft_datasets.TdwFlowDataset(
    root='/data5/dbear/tdw_datasets/playroom_large_v3copy/',
#     root='/mnt/fs5/dbear/tdw_datasets/playroom_large_v3/',
    dataset_names=['model_split_4'],    
#     dataset_names=['model_split_%d' % split for split in range(4)],
    split='training',
    filepattern="000*",
#     test_filepattern="0*[0-4]",
    test_filepattern="*9",
    min_start_frame=6,
    max_start_frame=6,
    scale_to_pixels=True,
    get_gt_flow=True,
    get_backward_frame=True
)
print(len(tdw_dataset))
print(tdw_dataset.is_test)
# Out:
# 10
# False
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# mprop = load_model(None, model_class='prop', 
#                    small=True, 
#                    cuda=True, 
#                    train=True, 
#                    num_sample_points=2048,
#                    affinity_nonlinearity='softmax',
#                    motion_thresh=0.5,
#                    binarize_motion=True,
#                    num_propagation_iters=50)

# mclass_teacher = load_model(None, model_class='motion', 
#                    small=True, 
#                    cuda=True, 
#                    train=True)


# mprop_student = load_model(None, model_class='prop', 
#                    small=True, 
#                    cuda=True, 
#                    train=True, 
#                    num_sample_points=2048,
#                    affinity_nonlinearity='softmax',
#                    motion_thresh=0.5,
#                    binarize_motion=True,
#                    num_propagation_iters=50)

IM = targets.IsMovingTarget(warp_radius=3, 
                            thresh=None, 
                            normalize_error=False, 
                            normalize_features=False).cuda()



raft_iters=12
loss_fn = nn.BCELoss(reduction='none')

def get_motion_target(img0, img1, img2, thresh=0.01):
    video = torch.stack([img0, img1, img2], 1).float() / 255.
    target = (IM(video)[:,0] > thresh).float()
    return target

def get_teacher_target(teacher, img0, img1, img2, thresh=0.25):
    motion_fwd = teacher(img1, img2, test_mode=False, iters=raft_iters)[-1]
#     motion_bck = teacher(img1, img0, test_mode=False, iters=raft_iters)[0]
    target = (torch.sigmoid(motion_fwd).detach() > thresh).float()
    return target

def train_step(data, model, optimizer, teacher=None, thresh=0.01, motion_scale=1.0, affinity_scale=1.0):
    
    optimizer.zero_grad()
    img1, img2, img0 = [d.cuda() for d in data[:3]]
    if teacher is None:
        target = get_motion_target(img0, img1, img2, thresh=target_thresh)
    else:
        target = get_teacher_target(teacher, img0, img1, img2, thresh=target_thresh)
    preds_list = model(img1, img2, test_mode=False, iters=raft_iters)
    
    if teacher is None:
        loss_list = [loss_fn(torch.sigmoid(pred), target).mean() for pred in preds_list]
        loss = motion_scale * (sum(loss_list) / len(loss_list))
    else:
        loss_list = [loss_fn(pred.clamp(max=1.), target).mean() for pred in preds_list]
        loss = motion_scale * loss_list[0] + affinity_scale * (sum(loss_list[1:]) / len(loss_list[1:]))
    loss.backward()
    optimizer.step()
    
    return (loss, loss_list)

def val_step(data, model, test_mode=True, motion_thresh=None):
    
    img1, img2, img0 = [d[None].cuda() for d in data[:3]]
    target = get_motion_target(img0, img1, img2, thresh=target_thresh)
    if motion_thresh is not None:
        model.module.propagator.thresh = motion_thresh
    preds = model(img1, img2, test_mode=test_mode, iters=raft_iters)
    return (preds, target)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
num_epochs = 100
num_steps = None
print_every = 10

rnd = 1

if rnd == 0:
    m_scale = 100.0
    a_scale = 0.
    teacher = None
    student = mclass_teacher
    target_thresh = 0.01
elif rnd == 1:
    m_scale = 100.
    a_scale = 100.
    teacher = mclass_teacher
    student = mprop_student
    target_thresh = 0.25

batch_size = 4
trainloader = torch.utils.data.DataLoader(tdw_dataset, 
                                          batch_size=batch_size,
                                          shuffle=True,
                                          pin_memory=False,
                                          num_workers=4,
                                          drop_last=True)
opt = torch.optim.Adam(student.parameters(), lr=0.0001)

for epoch in range(num_epochs):
    for step, data in enumerate(trainloader):
        if step == num_steps:
            break
        
        loss, loss_list = train_step(data=data, model=student, optimizer=opt, teacher=teacher,
                                     thresh=target_thresh,
                                     motion_scale=m_scale, affinity_scale=a_scale)
        if (step % print_every) == 0:
            print("epoch %d / step %d ---- loss first %.3f ---- loss last %.3f ---- loss total %.3f" % 
                  (epoch, step, loss_list[0].item(), loss_list[-1].item(), loss.item()))
            
    if step == num_steps:
        break
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# epoch 0 / step 0 ---- loss first 0.397 ---- loss last 2.547 ---- loss total 295.503
# epoch 1 / step 0 ---- loss first 0.336 ---- loss last 5.997 ---- loss total 633.251
# epoch 2 / step 0 ---- loss first 0.143 ---- loss last 2.693 ---- loss total 283.599
# epoch 3 / step 0 ---- loss first 0.139 ---- loss last 3.657 ---- loss total 379.577
# epoch 4 / step 0 ---- loss first 0.189 ---- loss last 2.790 ---- loss total 303.511
# epoch 5 / step 0 ---- loss first 0.191 ---- loss last 5.997 ---- loss total 618.765
# epoch 6 / step 0 ---- loss first 0.225 ---- loss last 6.838 ---- loss total 706.231
# epoch 7 / step 0 ---- loss first 0.097 ---- loss last 2.930 ---- loss total 302.699
# epoch 8 / step 0 ---- loss first 0.159 ---- loss last 5.264 ---- loss total 544.555
# epoch 9 / step 0 ---- loss first 0.104 ---- loss last 3.406 ---- loss total 357.389
# epoch 10 / step 0 ---- loss first 0.145 ---- loss last 5.106 ---- loss total 528.195
# epoch 11 / step 0 ---- loss first 0.082 ---- loss last 2.875 ---- loss total 295.663
# epoch 12 / step 0 ---- loss first 0.066 ---- loss last 2.032 ---- loss total 211.800
# epoch 13 / step 0 ---- loss first 0.136 ---- loss last 5.491 ---- loss total 563.913
# epoch 14 / step 0 ---- loss first 0.091 ---- loss last 1.318 ---- loss total 141.310
# epoch 15 / step 0 ---- loss first 0.089 ---- loss last 3.569 ---- loss total 370.888
# epoch 16 / step 0 ---- loss first 0.124 ---- loss last 5.361 ---- loss total 553.429
# epoch 17 / step 0 ---- loss first 0.068 ---- loss last 1.920 ---- loss total 201.581
# epoch 18 / step 0 ---- loss first 0.066 ---- loss last 1.977 ---- loss total 201.861
# epoch 19 / step 0 ---- loss first 0.109 ---- loss last 5.243 ---- loss total 541.094
# epoch 20 / step 0 ---- loss first 0.084 ---- loss last 4.088 ---- loss total 418.175
# epoch 21 / step 0 ---- loss first 0.061 ---- loss last 1.622 ---- loss total 168.067
# epoch 22 / step 0 ---- loss first 0.045 ---- loss last 1.726 ---- loss total 176.550
# epoch 23 / step 0 ---- loss first 0.071 ---- loss last 3.958 ---- loss total 400.882
# epoch 24 / step 0 ---- loss first 0.068 ---- loss last 3.807 ---- loss total 383.350
# epoch 25 / step 0 ---- loss first 0.066 ---- loss last 4.316 ---- loss total 437.294
# epoch 26 / step 0 ---- loss first 0.068 ---- loss last 2.667 ---- loss total 274.111
# epoch 27 / step 0 ---- loss first 0.056 ---- loss last 2.413 ---- loss total 247.069
# epoch 28 / step 0 ---- loss first 0.058 ---- loss last 3.845 ---- loss total 388.220
# epoch 29 / step 0 ---- loss first 0.051 ---- loss last 2.439 ---- loss total 250.972
# epoch 30 / step 0 ---- loss first 0.069 ---- loss last 4.211 ---- loss total 428.540
# epoch 31 / step 0 ---- loss first 0.055 ---- loss last 3.553 ---- loss total 360.603
# epoch 32 / step 0 ---- loss first 0.051 ---- loss last 2.017 ---- loss total 206.510
# epoch 33 / step 0 ---- loss first 0.067 ---- loss last 4.471 ---- loss total 455.335
# epoch 34 / step 0 ---- loss first 0.031 ---- loss last 1.020 ---- loss total 105.483
# epoch 35 / step 0 ---- loss first 0.046 ---- loss last 3.383 ---- loss total 342.179
# epoch 36 / step 0 ---- loss first 0.030 ---- loss last 1.476 ---- loss total 150.001
# epoch 37 / step 0 ---- loss first 0.037 ---- loss last 1.491 ---- loss total 151.919
# epoch 38 / step 0 ---- loss first 0.039 ---- loss last 1.979 ---- loss total 202.105
# epoch 39 / step 0 ---- loss first 0.037 ---- loss last 2.299 ---- loss total 232.841
# epoch 40 / step 0 ---- loss first 0.042 ---- loss last 3.398 ---- loss total 344.844
# epoch 41 / step 0 ---- loss first 0.028 ---- loss last 1.498 ---- loss total 152.844
# epoch 42 / step 0 ---- loss first 0.043 ---- loss last 3.571 ---- loss total 361.797
# epoch 43 / step 0 ---- loss first 0.041 ---- loss last 4.220 ---- loss total 427.189
# epoch 44 / step 0 ---- loss first 0.029 ---- loss last 3.396 ---- loss total 342.561
# epoch 45 / step 0 ---- loss first 0.021 ---- loss last 1.201 ---- loss total 122.427
# epoch 46 / step 0 ---- loss first 0.016 ---- loss last 0.699 ---- loss total 72.150
# epoch 47 / step 0 ---- loss first 0.017 ---- loss last 1.449 ---- loss total 146.976
# epoch 48 / step 0 ---- loss first 0.032 ---- loss last 3.359 ---- loss total 340.290
# epoch 49 / step 0 ---- loss first 0.028 ---- loss last 3.426 ---- loss total 342.558
# epoch 50 / step 0 ---- loss first 0.018 ---- loss last 1.156 ---- loss total 117.909
# epoch 51 / step 0 ---- loss first 0.016 ---- loss last 1.498 ---- loss total 150.974
# epoch 52 / step 0 ---- loss first 0.029 ---- loss last 3.256 ---- loss total 328.257
# epoch 53 / step 0 ---- loss first 0.024 ---- loss last 1.445 ---- loss total 145.978
# epoch 54 / step 0 ---- loss first 0.014 ---- loss last 1.069 ---- loss total 108.689
# epoch 55 / step 0 ---- loss first 0.032 ---- loss last 3.466 ---- loss total 349.568
# epoch 56 / step 0 ---- loss first 0.027 ---- loss last 3.166 ---- loss total 319.455
# epoch 57 / step 0 ---- loss first 0.026 ---- loss last 3.551 ---- loss total 356.475
# epoch 58 / step 0 ---- loss first 0.025 ---- loss last 1.960 ---- loss total 198.923
# epoch 59 / step 0 ---- loss first 0.014 ---- loss last 1.476 ---- loss total 149.098
# epoch 60 / step 0 ---- loss first 0.021 ---- loss last 1.609 ---- loss total 163.495
# epoch 61 / step 0 ---- loss first 0.022 ---- loss last 1.563 ---- loss total 160.580
# epoch 62 / step 0 ---- loss first 0.008 ---- loss last 0.862 ---- loss total 87.221
# epoch 63 / step 0 ---- loss first 0.022 ---- loss last 3.232 ---- loss total 323.926
# epoch 64 / step 0 ---- loss first 0.020 ---- loss last 1.694 ---- loss total 170.349
# epoch 65 / step 0 ---- loss first 0.024 ---- loss last 3.898 ---- loss total 393.555
# epoch 66 / step 0 ---- loss first 0.010 ---- loss last 0.882 ---- loss total 89.823
# epoch 67 / step 0 ---- loss first 0.016 ---- loss last 0.961 ---- loss total 97.285
# epoch 68 / step 0 ---- loss first 0.021 ---- loss last 3.521 ---- loss total 353.524
# epoch 69 / step 0 ---- loss first 0.024 ---- loss last 3.719 ---- loss total 374.443
# epoch 70 / step 0 ---- loss first 0.024 ---- loss last 1.225 ---- loss total 124.891
# epoch 71 / step 0 ---- loss first 0.033 ---- loss last 3.669 ---- loss total 368.879
# epoch 72 / step 0 ---- loss first 0.034 ---- loss last 3.681 ---- loss total 367.974
# epoch 73 / step 0 ---- loss first 0.024 ---- loss last 1.373 ---- loss total 139.636
# epoch 74 / step 0 ---- loss first 0.036 ---- loss last 1.189 ---- loss total 122.283
# epoch 75 / step 0 ---- loss first 0.033 ---- loss last 3.774 ---- loss total 380.159
# epoch 76 / step 0 ---- loss first 0.034 ---- loss last 1.601 ---- loss total 165.026
# epoch 77 / step 0 ---- loss first 0.022 ---- loss last 1.577 ---- loss total 157.399
# epoch 78 / step 0 ---- loss first 0.024 ---- loss last 0.994 ---- loss total 101.621
# epoch 79 / step 0 ---- loss first 0.023 ---- loss last 1.650 ---- loss total 168.087
# epoch 80 / step 0 ---- loss first 0.024 ---- loss last 1.394 ---- loss total 142.692
# epoch 81 / step 0 ---- loss first 0.040 ---- loss last 3.655 ---- loss total 368.376
# epoch 82 / step 0 ---- loss first 0.009 ---- loss last 0.626 ---- loss total 63.718
# epoch 83 / step 0 ---- loss first 0.040 ---- loss last 3.926 ---- loss total 398.245
# epoch 84 / step 0 ---- loss first 0.015 ---- loss last 0.848 ---- loss total 86.471
# epoch 85 / step 0 ---- loss first 0.024 ---- loss last 0.959 ---- loss total 97.935
# epoch 86 / step 0 ---- loss first 0.018 ---- loss last 1.072 ---- loss total 108.291
# epoch 87 / step 0 ---- loss first 0.020 ---- loss last 1.567 ---- loss total 158.660
# epoch 88 / step 0 ---- loss first 0.012 ---- loss last 1.210 ---- loss total 122.378
# epoch 89 / step 0 ---- loss first 0.015 ---- loss last 1.737 ---- loss total 175.614
# epoch 90 / step 0 ---- loss first 0.015 ---- loss last 1.423 ---- loss total 143.038
# epoch 91 / step 0 ---- loss first 0.018 ---- loss last 3.308 ---- loss total 333.681
# epoch 92 / step 0 ---- loss first 0.018 ---- loss last 3.112 ---- loss total 312.135
# epoch 93 / step 0 ---- loss first 0.009 ---- loss last 1.018 ---- loss total 102.520
# epoch 94 / step 0 ---- loss first 0.011 ---- loss last 1.197 ---- loss total 119.559
# epoch 95 / step 0 ---- loss first 0.013 ---- loss last 1.296 ---- loss total 131.661
# epoch 96 / step 0 ---- loss first 0.015 ---- loss last 1.900 ---- loss total 191.724
# epoch 97 / step 0 ---- loss first 0.014 ---- loss last 1.334 ---- loss total 135.682
# epoch 98 / step 0 ---- loss first 0.011 ---- loss last 1.563 ---- loss total 156.838
# epoch 99 / step 0 ---- loss first 0.016 ---- loss last 1.632 ---- loss total 164.258

# %%
ex = 9
teacher_preds, target = val_step(tdw_dataset[ex], mclass_teacher, test_mode=True, motion_thresh=None)
preds, target = val_step(tdw_dataset[ex], mprop_student, test_mode=True, motion_thresh=0.5)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(torch.sigmoid(teacher_preds[-1]) > 0.25, cmap='magma', vmin=0, vmax=preds[-1].amax()+1)
vis_utils.imshow(preds[-1], cmap='magma')
vis_utils.imshow(preds[0], cmap='twilight', vmin=0, vmax=preds[0].amax()*1.3)

vis_utils.imshow(target)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ex = 1
img1, img2, img0 = [d[None].cuda() for d in tdw_dataset[ex][:3]]
target = get_teacher_target(mprop, img0, img1, img2, thresh=0.25)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis_utils.imshow(target)
# Out:
# /home/dbear/tenv/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
